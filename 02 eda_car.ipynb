# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = pd.read_csv("cleaned_car_data.csv")

# %%
ds
# Out:
#      Unnamed: 0  index                            name   company  year  \
# 0             0      0    Santro Xing XO eRLX Euro III   Hyundai  2007
# 1             1      3  Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014
# 2             2      4     EcoSport Titanium 1.5L TDCi      Ford  2014
# 3             3      6                            Figo      Ford  2012
# 4             4      7                             Eon   Hyundai  2013
# ..          ...    ...                             ...       ...   ...
# 646         646    883             Suzuki Ritz VXI ABS    Maruti  2011
# 647         647    885            Indica V2 DLE BS III      Tata  2009
# 648         648    886                   Corolla Altis    Toyota  2009
# 649         649    888                  Zest XM Diesel      Tata  2018
# 650         650    889                       Quanto C8  Mahindra  2013
#
#         Price  kms_driven fuel_type
# 0     80000.0       45000    Petrol
# 1    325000.0       28000    Petrol
# ...

# %%
companywisecount = ds.groupby("company")["company"].count()

# %%
companywisecount.plot(kind = 'line')
# Out:
# <Axes: xlabel='company'>

# %%
companywisecount.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
companywisecount.plot(kind = 'bar')
# Out:
# <Axes: xlabel='company'>
